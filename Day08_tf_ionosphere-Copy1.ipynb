# %%
###-----------------
### Import Libraries
###-----------------

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import (accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay, f1_score)

# from utils.helper import fn_plot_confusion_matrix

# %%
def fn_plot_tf_hist(hist_df : pd.DataFrame):
    '''
    Note this function is specifically designed to plot Tensorflow training output
    Args:
      hist_df : pandas DataFrame with four columns
                For 'x' values, we will use index
                first column is accuracy
                Second column is loss
                third column is val_accuracy
                fourth column is val_loss
    '''
    fig, axes = plt.subplots(1,2 , figsize = (15,6)) # instantiate plot

    # properties  matplotlib.patch.Patch 
    props = dict(boxstyle='round', facecolor='aqua', alpha=0.4)
    facecolor = 'cyan'
    fontsize=12
    
    # Get columns by index to eliminate any column naming error
    y1 = hist_df.columns[0]
    y2 = hist_df.columns[1]
    y3 = hist_df.columns[2]
    y4 = hist_df.columns[3]

    # Where was min loss
    best = hist_df[hist_df[y4] == hist_df[y4].min()]
 
    ax = axes[0]

    hist_df.plot(y = [y2,y4], ax = ax, colormap=CMAP)


    # little beautification
    txtFmt = "Loss: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y2],
                           hist_df.iloc[-1][y4]) #text to plot
    
    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Min: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy()-1, best[y4].to_numpy()[0]), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow

    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y2.capitalize())
    ax.set_title('Errors')
    ax.legend(loc = 'upper left') # model legend to upper left

    ax = axes[1]

    hist_df.plot( y = [y1, y3], ax = ax, colormap=CMAP)
    
    # little beautification
    txtFmt = "Accuracy: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y3]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.2, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Best: {best[y3].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y3].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy()-1, best[y3].to_numpy()[0]), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow
    
    
    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y1.capitalize())
    ax.legend(loc = 'lower left')
    
    plt.tight_layout()

# %%
# Some basic parameters
inpDir = '../../../input' # location where input data is stored
outDir = '../output' # location to store outputs
subDir = 'fashion_MNIST' # location of the images
modelDir = '../models'
altName = 'all_in'

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
BATCH_SIZE = 32 # batch size for training   
TRAIN_SIZE = BATCH_SIZE * 9

EPOCHS = 100 # number of cycles to run
ALPHA = 0.001 # learning rate
WEIGHT_DECAY =0.001

# Set parameters for decoration of plots
params = {'legend.fontsize' : 'large',
          'figure.figsize'  : (9,9),
          'axes.labelsize'  : 'x-large',
          'axes.titlesize'  :'x-large',
          'xtick.labelsize' :'large',
          'ytick.labelsize' :'large',
         }

plt.rcParams.update(params) # update rcParams
CMAP = plt.cm.coolwarm
plt.style.use('seaborn-v0_8-darkgrid') # plt.style.use('ggplot')

# %%
data_df = pd.read_csv('ionosphere.data', header=None)

# %%
X = data_df.drop(data_df.columns[-1], axis = 1).to_numpy()
y = data_df[data_df.columns[-1]].to_numpy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size= TRAIN_SIZE, 
                                                    stratify=y, random_state=RANDOM_STATE)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((288, 34), (63, 34), (288,), (63,))

# %%
le = LabelEncoder()

y_train = le.fit_transform(y_train)

y_test = le.transform(y_test)

# %%
class_name = list(le.classes_)
class_name
# Out:
# ['b', 'g']

# %%
sc = StandardScaler()

X_train = sc.fit_transform(X_train)

X_test = sc.transform(X_test)

# %%
## Some Model Specification
rate1 = 0.05
rate2 = 0.15
rate3 = 0.25

initalizer = tf.keras.initializers.GlorotUniform(seed= RANDOM_STATE)
optimizer = tf.keras.optimizers.AdamW(learning_rate=ALPHA, weight_decay = WEIGHT_DECAY)
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits= True)

model1 = tf.keras.models.Sequential([
    tf.keras.layers.InputLayer(shape = (34,)),

    #SET1
    tf.keras.layers.Dense(26, kernel_initializer= initalizer),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation(activation = 'relu'),
    tf.keras.layers.Dropout(rate1, seed = RANDOM_STATE),

     #SET2
    tf.keras.layers.Dense(18, kernel_initializer= initalizer),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation(activation = 'relu'),
    tf.keras.layers.Dropout(rate2, seed = RANDOM_STATE),

     #SET3
    tf.keras.layers.Dense(10, kernel_initializer= initalizer),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation(activation = 'relu'),
    tf.keras.layers.Dropout(rate3, seed = RANDOM_STATE),


    tf.keras.layers.Dense(2)
])

model1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 26)             │           910 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 26)             │           104 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 26)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 26)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 18)             │           486 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 18)             │            72 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 18)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 18)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │           190 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 10)             │            40 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 10)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 10)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 2)              │            22 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,824 (7.12 KB)
#  Trainable params: 1,716 (6.70 KB)
#  Non-trainable params: 108 (432.00 B)

# %%
chkpt_filepath = os.path.join(modelDir, subDir,f'{altName}.weights.h5')

# %%
EPOCHS = 500
PATIENCE =20
LR_PATIENCE =10
LR_FACTOR = 0.1

model_chkpt = tf.keras.callbacks.ModelCheckpoint(
    chkpt_filepath,
    monitor='val_loss',
    verbose=2,
    save_best_only=True,
    save_weights_only=True,)

escb = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE,
    verbose=2,
    restore_best_weights=True)

lrcb = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=LR_FACTOR,
    patience=LR_PATIENCE,
    verbose=2,
    min_lr=1e-5)

# %%
# Step1: Loss Function
loss_fn =tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
#Step 2 : Optimizer

optimizer = tf.keras.optimizers.Adam(learning_rate=ALPHA)
#Step 3: 
model1.compile(loss = loss_fn, optimizer = optimizer, metrics=['accuracy'])

# Step 4 :

history = model1.fit(X_train, y_train,callbacks=[model_chkpt, escb, lrcb],
                    epochs= EPOCHS,
                    validation_data=(X_test,y_test))

# Defaulted BATCH_SIZE, verbose =0
# Out:
# Epoch 1/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.6250 - loss: 0.8884
# Epoch 1: val_loss improved from inf to 0.78219, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.5169 - loss: 0.9529 - val_accuracy: 0.3651 - val_loss: 0.7822 - learning_rate: 0.0010
# Epoch 2/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5312 - loss: 0.7767
# Epoch 2: val_loss improved from 0.78219 to 0.72379, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5114 - loss: 0.7751 - val_accuracy: 0.3651 - val_loss: 0.7238 - learning_rate: 0.0010
# Epoch 3/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6562 - loss: 0.6762
# Epoch 3: val_loss improved from 0.72379 to 0.66859, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6017 - loss: 0.7175 - val_accuracy: 0.4127 - val_loss: 0.6686 - learning_rate: 0.0010
# Epoch 4/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5312 - loss: 0.7114
# Epoch 4: val_loss improved from 0.66859 to 0.61448, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6200 - loss: 0.6657 - val_accuracy: 0.4762 - val_loss: 0.6145 - learning_rate: 0.0010
# Epoch 5/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6562 - loss: 0.7262
# Epoch 5: val_loss improved from 0.61448 to 0.56775, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7174 - loss: 0.6339 - val_accuracy: 0.5714 - val_loss: 0.5678 - learning_rate: 0.0010
# Epoch 6/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7188 - loss: 0.5300
# Epoch 6: val_loss improved from 0.56775 to 0.53043, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7227 - loss: 0.5580 - val_accuracy: 0.8095 - val_loss: 0.5304 - learning_rate: 0.0010
# Epoch 7/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8438 - loss: 0.5406
# Epoch 7: val_loss improved from 0.53043 to 0.49750, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8020 - loss: 0.5253 - val_accuracy: 0.8889 - val_loss: 0.4975 - learning_rate: 0.0010
# Epoch 8/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9062 - loss: 0.4291
# Epoch 8: val_loss improved from 0.49750 to 0.47143, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8428 - loss: 0.4962 - val_accuracy: 0.9365 - val_loss: 0.4714 - learning_rate: 0.0010
# Epoch 9/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8438 - loss: 0.4590
# Epoch 9: val_loss improved from 0.47143 to 0.44909, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8190 - loss: 0.4746 - val_accuracy: 0.9048 - val_loss: 0.4491 - learning_rate: 0.0010
# Epoch 10/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8125 - loss: 0.4438
# Epoch 10: val_loss improved from 0.44909 to 0.42919, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8761 - loss: 0.4160 - val_accuracy: 0.9048 - val_loss: 0.4292 - learning_rate: 0.0010
# Epoch 11/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8438 - loss: 0.4734
# Epoch 11: val_loss improved from 0.42919 to 0.41090, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8389 - loss: 0.4919 - val_accuracy: 0.9365 - val_loss: 0.4109 - learning_rate: 0.0010
# Epoch 12/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8438 - loss: 0.4674
# Epoch 12: val_loss improved from 0.41090 to 0.39308, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8697 - loss: 0.4331 - val_accuracy: 0.9365 - val_loss: 0.3931 - learning_rate: 0.0010
# Epoch 13/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9688 - loss: 0.3521
# Epoch 13: val_loss improved from 0.39308 to 0.37549, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8886 - loss: 0.4074 - val_accuracy: 0.9524 - val_loss: 0.3755 - learning_rate: 0.0010
# Epoch 14/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8125 - loss: 0.4447
# Epoch 14: val_loss improved from 0.37549 to 0.35765, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8561 - loss: 0.4279 - val_accuracy: 0.9524 - val_loss: 0.3577 - learning_rate: 0.0010
# Epoch 15/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9688 - loss: 0.3524
# Epoch 15: val_loss improved from 0.35765 to 0.34165, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9366 - loss: 0.3461 - val_accuracy: 0.9683 - val_loss: 0.3416 - learning_rate: 0.0010
# Epoch 16/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9688 - loss: 0.3124
# Epoch 16: val_loss improved from 0.34165 to 0.32622, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9026 - loss: 0.3712 - val_accuracy: 0.9683 - val_loss: 0.3262 - learning_rate: 0.0010
# Epoch 17/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9375 - loss: 0.3209
# Epoch 17: val_loss improved from 0.32622 to 0.31387, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9052 - loss: 0.3543 - val_accuracy: 0.9683 - val_loss: 0.3139 - learning_rate: 0.0010
# Epoch 18/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9375 - loss: 0.3302
# Epoch 18: val_loss improved from 0.31387 to 0.30182, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9287 - loss: 0.3293 - val_accuracy: 0.9524 - val_loss: 0.3018 - learning_rate: 0.0010
# Epoch 19/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7812 - loss: 0.3666
# Epoch 19: val_loss improved from 0.30182 to 0.29160, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8820 - loss: 0.3424 - val_accuracy: 0.9524 - val_loss: 0.2916 - learning_rate: 0.0010
# Epoch 20/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8125 - loss: 0.3382
# Epoch 20: val_loss improved from 0.29160 to 0.28281, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8869 - loss: 0.3172 - val_accuracy: 0.9365 - val_loss: 0.2828 - learning_rate: 0.0010
# Epoch 21/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8438 - loss: 0.3776
# Epoch 21: val_loss improved from 0.28281 to 0.27401, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8985 - loss: 0.3309 - val_accuracy: 0.9365 - val_loss: 0.2740 - learning_rate: 0.0010
# Epoch 22/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9062 - loss: 0.3901
# Epoch 22: val_loss improved from 0.27401 to 0.26496, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9247 - loss: 0.3266 - val_accuracy: 0.9365 - val_loss: 0.2650 - learning_rate: 0.0010
# Epoch 23/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8750 - loss: 0.3509
# Epoch 23: val_loss improved from 0.26496 to 0.25640, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9093 - loss: 0.3206 - val_accuracy: 0.9365 - val_loss: 0.2564 - learning_rate: 0.0010
# Epoch 24/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.2072
# Epoch 24: val_loss improved from 0.25640 to 0.24861, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9320 - loss: 0.2837 - val_accuracy: 0.9365 - val_loss: 0.2486 - learning_rate: 0.0010
# Epoch 25/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9062 - loss: 0.2953
# Epoch 25: val_loss improved from 0.24861 to 0.23995, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9351 - loss: 0.2738 - val_accuracy: 0.9365 - val_loss: 0.2400 - learning_rate: 0.0010
# Epoch 26/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8750 - loss: 0.4308
# Epoch 26: val_loss improved from 0.23995 to 0.23212, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8981 - loss: 0.3446 - val_accuracy: 0.9365 - val_loss: 0.2321 - learning_rate: 0.0010
# Epoch 27/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9062 - loss: 0.2591
# Epoch 27: val_loss improved from 0.23212 to 0.22609, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9108 - loss: 0.2815 - val_accuracy: 0.9365 - val_loss: 0.2261 - learning_rate: 0.0010
# Epoch 28/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9688 - loss: 0.2235
# Epoch 28: val_loss improved from 0.22609 to 0.21957, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9330 - loss: 0.2562 - val_accuracy: 0.9365 - val_loss: 0.2196 - learning_rate: 0.0010
# Epoch 29/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9375 - loss: 0.2806
# Epoch 29: val_loss improved from 0.21957 to 0.21357, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9189 - loss: 0.2774 - val_accuracy: 0.9365 - val_loss: 0.2136 - learning_rate: 0.0010
# Epoch 30/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9688 - loss: 0.1941
# Epoch 30: val_loss improved from 0.21357 to 0.20438, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9321 - loss: 0.2487 - val_accuracy: 0.9206 - val_loss: 0.2044 - learning_rate: 0.0010
# Epoch 31/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9062 - loss: 0.2116
# Epoch 31: val_loss improved from 0.20438 to 0.19776, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9239 - loss: 0.2343 - val_accuracy: 0.9206 - val_loss: 0.1978 - learning_rate: 0.0010
# Epoch 32/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.1708
# Epoch 32: val_loss improved from 0.19776 to 0.19120, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9419 - loss: 0.2200 - val_accuracy: 0.9206 - val_loss: 0.1912 - learning_rate: 0.0010
# Epoch 33/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9375 - loss: 0.2539
# Epoch 33: val_loss improved from 0.19120 to 0.18428, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9646 - loss: 0.2132 - val_accuracy: 0.9206 - val_loss: 0.1843 - learning_rate: 0.0010
# Epoch 34/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9375 - loss: 0.2158
# Epoch 34: val_loss improved from 0.18428 to 0.17876, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9509 - loss: 0.2211 - val_accuracy: 0.9206 - val_loss: 0.1788 - learning_rate: 0.0010
# Epoch 35/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8438 - loss: 0.3548
# Epoch 35: val_loss improved from 0.17876 to 0.17250, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9151 - loss: 0.2382 - val_accuracy: 0.9524 - val_loss: 0.1725 - learning_rate: 0.0010
# Epoch 36/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.1630
# Epoch 36: val_loss improved from 0.17250 to 0.16601, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9511 - loss: 0.2031 - val_accuracy: 0.9524 - val_loss: 0.1660 - learning_rate: 0.0010
# Epoch 37/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.1233
# Epoch 37: val_loss improved from 0.16601 to 0.15979, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9699 - loss: 0.1759 - val_accuracy: 0.9524 - val_loss: 0.1598 - learning_rate: 0.0010
# Epoch 38/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.1655
# Epoch 38: val_loss improved from 0.15979 to 0.15327, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9300 - loss: 0.2223 - val_accuracy: 0.9524 - val_loss: 0.1533 - learning_rate: 0.0010
# Epoch 39/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9062 - loss: 0.2108
# Epoch 39: val_loss improved from 0.15327 to 0.14877, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9340 - loss: 0.2152 - val_accuracy: 0.9524 - val_loss: 0.1488 - learning_rate: 0.0010
# Epoch 40/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9375 - loss: 0.1539
# Epoch 40: val_loss improved from 0.14877 to 0.14493, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9495 - loss: 0.1857 - val_accuracy: 0.9524 - val_loss: 0.1449 - learning_rate: 0.0010
# Epoch 41/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9688 - loss: 0.1852
# Epoch 41: val_loss improved from 0.14493 to 0.14289, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9772 - loss: 0.1653 - val_accuracy: 0.9524 - val_loss: 0.1429 - learning_rate: 0.0010
# Epoch 42/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.1604
# Epoch 42: val_loss improved from 0.14289 to 0.14078, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9318 - loss: 0.2076 - val_accuracy: 0.9524 - val_loss: 0.1408 - learning_rate: 0.0010
# Epoch 43/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.1741
# Epoch 43: val_loss improved from 0.14078 to 0.13796, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9467 - loss: 0.1880 - val_accuracy: 0.9524 - val_loss: 0.1380 - learning_rate: 0.0010
# Epoch 44/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9375 - loss: 0.2090
# Epoch 44: val_loss improved from 0.13796 to 0.13461, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9512 - loss: 0.1929 - val_accuracy: 0.9683 - val_loss: 0.1346 - learning_rate: 0.0010
# Epoch 45/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9375 - loss: 0.1555
# Epoch 45: val_loss improved from 0.13461 to 0.13374, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9448 - loss: 0.1895 - val_accuracy: 0.9683 - val_loss: 0.1337 - learning_rate: 0.0010
# Epoch 46/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9688 - loss: 0.1374
# Epoch 46: val_loss improved from 0.13374 to 0.13054, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9645 - loss: 0.1522 - val_accuracy: 0.9683 - val_loss: 0.1305 - learning_rate: 0.0010
# Epoch 47/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9375 - loss: 0.2193
# Epoch 47: val_loss improved from 0.13054 to 0.12396, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9226 - loss: 0.2386 - val_accuracy: 0.9683 - val_loss: 0.1240 - learning_rate: 0.0010
# Epoch 48/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0729
# Epoch 48: val_loss improved from 0.12396 to 0.12138, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9705 - loss: 0.1407 - val_accuracy: 0.9683 - val_loss: 0.1214 - learning_rate: 0.0010
# Epoch 49/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.1857
# Epoch 49: val_loss improved from 0.12138 to 0.11851, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9277 - loss: 0.1917 - val_accuracy: 0.9683 - val_loss: 0.1185 - learning_rate: 0.0010
# Epoch 50/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9375 - loss: 0.1557
# Epoch 50: val_loss improved from 0.11851 to 0.11485, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9370 - loss: 0.1719 - val_accuracy: 0.9683 - val_loss: 0.1149 - learning_rate: 0.0010
# Epoch 51/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.1407
# Epoch 51: val_loss improved from 0.11485 to 0.11216, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9658 - loss: 0.1431 - val_accuracy: 0.9683 - val_loss: 0.1122 - learning_rate: 0.0010
# Epoch 52/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.1168
# Epoch 52: val_loss improved from 0.11216 to 0.11046, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9695 - loss: 0.1547 - val_accuracy: 0.9683 - val_loss: 0.1105 - learning_rate: 0.0010
# Epoch 53/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9375 - loss: 0.1984
# Epoch 53: val_loss improved from 0.11046 to 0.10559, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9226 - loss: 0.2138 - val_accuracy: 0.9841 - val_loss: 0.1056 - learning_rate: 0.0010
# Epoch 54/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9688 - loss: 0.1880
# Epoch 54: val_loss improved from 0.10559 to 0.10155, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.1623 - val_accuracy: 0.9841 - val_loss: 0.1015 - learning_rate: 0.0010
# Epoch 55/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9375 - loss: 0.1086
# Epoch 55: val_loss improved from 0.10155 to 0.09786, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9587 - loss: 0.1393 - val_accuracy: 0.9841 - val_loss: 0.0979 - learning_rate: 0.0010
# Epoch 56/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9688 - loss: 0.1277
# Epoch 56: val_loss improved from 0.09786 to 0.09543, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9592 - loss: 0.1309 - val_accuracy: 0.9841 - val_loss: 0.0954 - learning_rate: 0.0010
# Epoch 57/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0828
# Epoch 57: val_loss improved from 0.09543 to 0.09122, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9729 - loss: 0.1220 - val_accuracy: 0.9841 - val_loss: 0.0912 - learning_rate: 0.0010
# Epoch 58/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9062 - loss: 0.2165
# Epoch 58: val_loss improved from 0.09122 to 0.08917, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9545 - loss: 0.1631 - val_accuracy: 0.9841 - val_loss: 0.0892 - learning_rate: 0.0010
# Epoch 59/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9375 - loss: 0.1436
# Epoch 59: val_loss improved from 0.08917 to 0.08881, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9536 - loss: 0.1404 - val_accuracy: 0.9841 - val_loss: 0.0888 - learning_rate: 0.0010
# Epoch 60/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9688 - loss: 0.0795
# Epoch 60: val_loss improved from 0.08881 to 0.08762, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9661 - loss: 0.1199 - val_accuracy: 0.9841 - val_loss: 0.0876 - learning_rate: 0.0010
# Epoch 61/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9688 - loss: 0.1544
# Epoch 61: val_loss did not improve from 0.08762
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9553 - loss: 0.1631 - val_accuracy: 0.9841 - val_loss: 0.0888 - learning_rate: 0.0010
# Epoch 62/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9375 - loss: 0.2403
# Epoch 62: val_loss improved from 0.08762 to 0.08548, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9640 - loss: 0.1649 - val_accuracy: 0.9841 - val_loss: 0.0855 - learning_rate: 0.0010
# Epoch 63/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9375 - loss: 0.1182
# Epoch 63: val_loss improved from 0.08548 to 0.08326, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9469 - loss: 0.1486 - val_accuracy: 0.9841 - val_loss: 0.0833 - learning_rate: 0.0010
# Epoch 64/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.1016
# Epoch 64: val_loss improved from 0.08326 to 0.08210, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9648 - loss: 0.1212 - val_accuracy: 0.9841 - val_loss: 0.0821 - learning_rate: 0.0010
# Epoch 65/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9688 - loss: 0.1389
# Epoch 65: val_loss improved from 0.08210 to 0.08139, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9740 - loss: 0.1269 - val_accuracy: 0.9683 - val_loss: 0.0814 - learning_rate: 0.0010
# Epoch 66/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.1102
# Epoch 66: val_loss improved from 0.08139 to 0.07927, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9526 - loss: 0.1500 - val_accuracy: 0.9683 - val_loss: 0.0793 - learning_rate: 0.0010
# Epoch 67/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.0959
# Epoch 67: val_loss improved from 0.07927 to 0.07859, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9511 - loss: 0.1471 - val_accuracy: 0.9683 - val_loss: 0.0786 - learning_rate: 0.0010
# Epoch 68/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9375 - loss: 0.2119
# Epoch 68: val_loss improved from 0.07859 to 0.07820, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9610 - loss: 0.1305 - val_accuracy: 0.9683 - val_loss: 0.0782 - learning_rate: 0.0010
# Epoch 69/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9375 - loss: 0.2109
# Epoch 69: val_loss improved from 0.07820 to 0.07641, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9672 - loss: 0.1379 - val_accuracy: 0.9683 - val_loss: 0.0764 - learning_rate: 0.0010
# Epoch 70/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9062 - loss: 0.2696
# Epoch 70: val_loss improved from 0.07641 to 0.07241, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9524 - loss: 0.1500 - val_accuracy: 0.9841 - val_loss: 0.0724 - learning_rate: 0.0010
# Epoch 71/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.1043
# Epoch 71: val_loss improved from 0.07241 to 0.07219, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9571 - loss: 0.1348 - val_accuracy: 0.9841 - val_loss: 0.0722 - learning_rate: 0.0010
# Epoch 72/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9375 - loss: 0.2065
# Epoch 72: val_loss improved from 0.07219 to 0.07119, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9579 - loss: 0.1505 - val_accuracy: 0.9683 - val_loss: 0.0712 - learning_rate: 0.0010
# Epoch 73/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.1170
# Epoch 73: val_loss improved from 0.07119 to 0.07016, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9806 - loss: 0.1171 - val_accuracy: 0.9683 - val_loss: 0.0702 - learning_rate: 0.0010
# Epoch 74/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9062 - loss: 0.1475
# Epoch 74: val_loss did not improve from 0.07016
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9524 - loss: 0.1196 - val_accuracy: 0.9683 - val_loss: 0.0716 - learning_rate: 0.0010
# Epoch 75/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0591
# Epoch 75: val_loss did not improve from 0.07016
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9830 - loss: 0.0957 - val_accuracy: 0.9683 - val_loss: 0.0714 - learning_rate: 0.0010
# Epoch 76/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.0649
# Epoch 76: val_loss did not improve from 0.07016
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9809 - loss: 0.0881 - val_accuracy: 0.9841 - val_loss: 0.0703 - learning_rate: 0.0010
# Epoch 77/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0795
# Epoch 77: val_loss improved from 0.07016 to 0.06770, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9690 - loss: 0.1102 - val_accuracy: 0.9841 - val_loss: 0.0677 - learning_rate: 0.0010
# Epoch 78/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9062 - loss: 0.1611
# Epoch 78: val_loss improved from 0.06770 to 0.06669, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9487 - loss: 0.1378 - val_accuracy: 0.9841 - val_loss: 0.0667 - learning_rate: 0.0010
# Epoch 79/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9688 - loss: 0.0903
# Epoch 79: val_loss improved from 0.06669 to 0.06617, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9695 - loss: 0.0921 - val_accuracy: 0.9841 - val_loss: 0.0662 - learning_rate: 0.0010
# Epoch 80/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0783
# Epoch 80: val_loss improved from 0.06617 to 0.06480, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9826 - loss: 0.1147 - val_accuracy: 0.9841 - val_loss: 0.0648 - learning_rate: 0.0010
# Epoch 81/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.0697
# Epoch 81: val_loss improved from 0.06480 to 0.05988, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9758 - loss: 0.0739 - val_accuracy: 0.9841 - val_loss: 0.0599 - learning_rate: 0.0010
# Epoch 82/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0312
# Epoch 82: val_loss improved from 0.05988 to 0.05691, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9736 - loss: 0.1065 - val_accuracy: 0.9841 - val_loss: 0.0569 - learning_rate: 0.0010
# Epoch 83/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.1547
# Epoch 83: val_loss improved from 0.05691 to 0.05674, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9544 - loss: 0.1423 - val_accuracy: 0.9841 - val_loss: 0.0567 - learning_rate: 0.0010
# Epoch 84/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9688 - loss: 0.0800
# Epoch 84: val_loss did not improve from 0.05674
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9624 - loss: 0.1358 - val_accuracy: 0.9841 - val_loss: 0.0601 - learning_rate: 0.0010
# Epoch 85/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9688 - loss: 0.0708
# Epoch 85: val_loss did not improve from 0.05674
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9690 - loss: 0.1181 - val_accuracy: 0.9841 - val_loss: 0.0622 - learning_rate: 0.0010
# Epoch 86/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9375 - loss: 0.1814
# Epoch 86: val_loss did not improve from 0.05674
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9491 - loss: 0.1312 - val_accuracy: 0.9841 - val_loss: 0.0624 - learning_rate: 0.0010
# Epoch 87/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9375 - loss: 0.1686
# Epoch 87: val_loss did not improve from 0.05674
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9689 - loss: 0.1271 - val_accuracy: 0.9841 - val_loss: 0.0633 - learning_rate: 0.0010
# Epoch 88/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.1170
# Epoch 88: val_loss did not improve from 0.05674
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9793 - loss: 0.1064 - val_accuracy: 0.9841 - val_loss: 0.0632 - learning_rate: 0.0010
# Epoch 89/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.0598
# Epoch 89: val_loss did not improve from 0.05674
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9596 - loss: 0.1266 - val_accuracy: 0.9841 - val_loss: 0.0639 - learning_rate: 0.0010
# Epoch 90/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0601
# Epoch 90: val_loss did not improve from 0.05674
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9809 - loss: 0.0844 - val_accuracy: 0.9841 - val_loss: 0.0648 - learning_rate: 0.0010
# Epoch 91/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9375 - loss: 0.1181
# Epoch 91: val_loss did not improve from 0.05674
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9544 - loss: 0.1196 - val_accuracy: 0.9841 - val_loss: 0.0625 - learning_rate: 0.0010
# Epoch 92/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.0720
# Epoch 92: val_loss did not improve from 0.05674
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9692 - loss: 0.0930 - val_accuracy: 0.9683 - val_loss: 0.0584 - learning_rate: 0.0010
# Epoch 93/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.1182
# Epoch 93: val_loss did not improve from 0.05674
#
# Epoch 93: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9619 - loss: 0.1187 - val_accuracy: 0.9841 - val_loss: 0.0571 - learning_rate: 0.0010
# Epoch 94/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9375 - loss: 0.1662
# Epoch 94: val_loss did not improve from 0.05674
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9617 - loss: 0.1257 - val_accuracy: 0.9841 - val_loss: 0.0569 - learning_rate: 1.0000e-04
# Epoch 95/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.1137
# Epoch 95: val_loss did not improve from 0.05674
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9697 - loss: 0.0973 - val_accuracy: 0.9841 - val_loss: 0.0569 - learning_rate: 1.0000e-04
# Epoch 96/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9062 - loss: 0.1376
# Epoch 96: val_loss did not improve from 0.05674
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9395 - loss: 0.1458 - val_accuracy: 0.9841 - val_loss: 0.0568 - learning_rate: 1.0000e-04
# Epoch 97/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9062 - loss: 0.2534
# Epoch 97: val_loss did not improve from 0.05674
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9496 - loss: 0.1463 - val_accuracy: 0.9683 - val_loss: 0.0571 - learning_rate: 1.0000e-04
# Epoch 98/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.1198
# Epoch 98: val_loss did not improve from 0.05674
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9816 - loss: 0.1165 - val_accuracy: 0.9683 - val_loss: 0.0569 - learning_rate: 1.0000e-04
# Epoch 99/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0739
# Epoch 99: val_loss did not improve from 0.05674
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9871 - loss: 0.0976 - val_accuracy: 0.9683 - val_loss: 0.0569 - learning_rate: 1.0000e-04
# Epoch 100/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.0561
# Epoch 100: val_loss improved from 0.05674 to 0.05673, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9667 - loss: 0.1085 - val_accuracy: 0.9841 - val_loss: 0.0567 - learning_rate: 1.0000e-04
# Epoch 101/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0783
# Epoch 101: val_loss improved from 0.05673 to 0.05645, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9759 - loss: 0.0958 - val_accuracy: 0.9841 - val_loss: 0.0565 - learning_rate: 1.0000e-04
# Epoch 102/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9062 - loss: 0.2191
# Epoch 102: val_loss improved from 0.05645 to 0.05645, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9526 - loss: 0.1326 - val_accuracy: 0.9841 - val_loss: 0.0564 - learning_rate: 1.0000e-04
# Epoch 103/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9375 - loss: 0.1621
# Epoch 103: val_loss did not improve from 0.05645
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9608 - loss: 0.1263 - val_accuracy: 0.9841 - val_loss: 0.0567 - learning_rate: 1.0000e-04
# Epoch 104/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9375 - loss: 0.1082
# Epoch 104: val_loss improved from 0.05645 to 0.05625, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9408 - loss: 0.1715 - val_accuracy: 0.9841 - val_loss: 0.0562 - learning_rate: 1.0000e-04
# Epoch 105/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9688 - loss: 0.1965
# Epoch 105: val_loss improved from 0.05625 to 0.05573, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9776 - loss: 0.1101 - val_accuracy: 0.9841 - val_loss: 0.0557 - learning_rate: 1.0000e-04
# Epoch 106/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0276
# Epoch 106: val_loss improved from 0.05573 to 0.05553, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9807 - loss: 0.0676 - val_accuracy: 0.9841 - val_loss: 0.0555 - learning_rate: 1.0000e-04
# Epoch 107/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0334
# Epoch 107: val_loss improved from 0.05553 to 0.05549, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9761 - loss: 0.0988 - val_accuracy: 0.9841 - val_loss: 0.0555 - learning_rate: 1.0000e-04
# Epoch 108/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9375 - loss: 0.1947
# Epoch 108: val_loss improved from 0.05549 to 0.05540, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9639 - loss: 0.1402 - val_accuracy: 0.9841 - val_loss: 0.0554 - learning_rate: 1.0000e-04
# Epoch 109/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.0734
# Epoch 109: val_loss did not improve from 0.05540
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9691 - loss: 0.1105 - val_accuracy: 0.9841 - val_loss: 0.0555 - learning_rate: 1.0000e-04
# Epoch 110/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0656
# Epoch 110: val_loss did not improve from 0.05540
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9652 - loss: 0.1251 - val_accuracy: 0.9841 - val_loss: 0.0557 - learning_rate: 1.0000e-04
# Epoch 111/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9688 - loss: 0.0930
# Epoch 111: val_loss did not improve from 0.05540
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9688 - loss: 0.0963 - val_accuracy: 0.9841 - val_loss: 0.0556 - learning_rate: 1.0000e-04
# Epoch 112/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9688 - loss: 0.1640
# Epoch 112: val_loss did not improve from 0.05540
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9754 - loss: 0.1177 - val_accuracy: 0.9841 - val_loss: 0.0554 - learning_rate: 1.0000e-04
# Epoch 113/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9375 - loss: 0.1274
# Epoch 113: val_loss did not improve from 0.05540
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9505 - loss: 0.1091 - val_accuracy: 0.9841 - val_loss: 0.0556 - learning_rate: 1.0000e-04
# Epoch 114/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.1467
# Epoch 114: val_loss did not improve from 0.05540
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9567 - loss: 0.1763 - val_accuracy: 0.9841 - val_loss: 0.0555 - learning_rate: 1.0000e-04
# Epoch 115/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0630
# Epoch 115: val_loss improved from 0.05540 to 0.05498, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9838 - loss: 0.0882 - val_accuracy: 0.9841 - val_loss: 0.0550 - learning_rate: 1.0000e-04
# Epoch 116/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9688 - loss: 0.1192
# Epoch 116: val_loss improved from 0.05498 to 0.05444, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9854 - loss: 0.0788 - val_accuracy: 0.9841 - val_loss: 0.0544 - learning_rate: 1.0000e-04
# Epoch 117/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.1661
# Epoch 117: val_loss improved from 0.05444 to 0.05409, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9659 - loss: 0.1057 - val_accuracy: 0.9841 - val_loss: 0.0541 - learning_rate: 1.0000e-04
# Epoch 118/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9375 - loss: 0.1359
# Epoch 118: val_loss improved from 0.05409 to 0.05392, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9556 - loss: 0.1126 - val_accuracy: 0.9841 - val_loss: 0.0539 - learning_rate: 1.0000e-04
# Epoch 119/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9688 - loss: 0.0737
# Epoch 119: val_loss did not improve from 0.05392
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9667 - loss: 0.1066 - val_accuracy: 0.9841 - val_loss: 0.0540 - learning_rate: 1.0000e-04
# Epoch 120/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9688 - loss: 0.1471
# Epoch 120: val_loss did not improve from 0.05392
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9780 - loss: 0.0982 - val_accuracy: 0.9841 - val_loss: 0.0543 - learning_rate: 1.0000e-04
# Epoch 121/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9688 - loss: 0.0860
# Epoch 121: val_loss did not improve from 0.05392
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9816 - loss: 0.0938 - val_accuracy: 0.9841 - val_loss: 0.0545 - learning_rate: 1.0000e-04
# Epoch 122/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9062 - loss: 0.3448
# Epoch 122: val_loss did not improve from 0.05392
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9544 - loss: 0.1652 - val_accuracy: 0.9841 - val_loss: 0.0545 - learning_rate: 1.0000e-04
# Epoch 123/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.1571
# Epoch 123: val_loss did not improve from 0.05392
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9659 - loss: 0.1161 - val_accuracy: 0.9841 - val_loss: 0.0542 - learning_rate: 1.0000e-04
# Epoch 124/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0422
# Epoch 124: val_loss did not improve from 0.05392
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9848 - loss: 0.0887 - val_accuracy: 0.9841 - val_loss: 0.0540 - learning_rate: 1.0000e-04
# Epoch 125/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.0690
# Epoch 125: val_loss improved from 0.05392 to 0.05330, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9492 - loss: 0.1492 - val_accuracy: 0.9841 - val_loss: 0.0533 - learning_rate: 1.0000e-04
# Epoch 126/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0535
# Epoch 126: val_loss improved from 0.05330 to 0.05283, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9761 - loss: 0.0846 - val_accuracy: 0.9841 - val_loss: 0.0528 - learning_rate: 1.0000e-04
# Epoch 127/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0297
# Epoch 127: val_loss did not improve from 0.05283
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9852 - loss: 0.0702 - val_accuracy: 0.9841 - val_loss: 0.0529 - learning_rate: 1.0000e-04
# Epoch 128/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0398
# Epoch 128: val_loss did not improve from 0.05283
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9789 - loss: 0.0785 - val_accuracy: 0.9841 - val_loss: 0.0529 - learning_rate: 1.0000e-04
# Epoch 129/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9375 - loss: 0.0924
# Epoch 129: val_loss did not improve from 0.05283
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9657 - loss: 0.0770 - val_accuracy: 0.9841 - val_loss: 0.0530 - learning_rate: 1.0000e-04
# Epoch 130/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0307
# Epoch 130: val_loss did not improve from 0.05283
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9667 - loss: 0.1102 - val_accuracy: 0.9841 - val_loss: 0.0531 - learning_rate: 1.0000e-04
# Epoch 131/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0513
# Epoch 131: val_loss improved from 0.05283 to 0.05278, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9819 - loss: 0.0885 - val_accuracy: 0.9841 - val_loss: 0.0528 - learning_rate: 1.0000e-04
# Epoch 132/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9375 - loss: 0.5319
# Epoch 132: val_loss did not improve from 0.05278
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9654 - loss: 0.2160 - val_accuracy: 0.9841 - val_loss: 0.0528 - learning_rate: 1.0000e-04
# Epoch 133/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0245
# Epoch 133: val_loss did not improve from 0.05278
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9822 - loss: 0.0780 - val_accuracy: 0.9841 - val_loss: 0.0528 - learning_rate: 1.0000e-04
# Epoch 134/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.1110
# Epoch 134: val_loss improved from 0.05278 to 0.05270, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9848 - loss: 0.0779 - val_accuracy: 0.9841 - val_loss: 0.0527 - learning_rate: 1.0000e-04
# Epoch 135/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.0676
# Epoch 135: val_loss did not improve from 0.05270
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9631 - loss: 0.1097 - val_accuracy: 0.9841 - val_loss: 0.0527 - learning_rate: 1.0000e-04
# Epoch 136/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9688 - loss: 0.1069
# Epoch 136: val_loss improved from 0.05270 to 0.05245, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9568 - loss: 0.1090 - val_accuracy: 0.9841 - val_loss: 0.0525 - learning_rate: 1.0000e-04
# Epoch 137/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9688 - loss: 0.1057
# Epoch 137: val_loss improved from 0.05245 to 0.05231, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9675 - loss: 0.1038 - val_accuracy: 0.9841 - val_loss: 0.0523 - learning_rate: 1.0000e-04
# Epoch 138/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9688 - loss: 0.1049
# Epoch 138: val_loss improved from 0.05231 to 0.05224, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9845 - loss: 0.0787 - val_accuracy: 0.9841 - val_loss: 0.0522 - learning_rate: 1.0000e-04
# Epoch 139/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9688 - loss: 0.1157
# Epoch 139: val_loss improved from 0.05224 to 0.05205, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9775 - loss: 0.0984 - val_accuracy: 0.9841 - val_loss: 0.0521 - learning_rate: 1.0000e-04
# Epoch 140/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9375 - loss: 0.1638
# Epoch 140: val_loss did not improve from 0.05205
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9566 - loss: 0.1333 - val_accuracy: 0.9841 - val_loss: 0.0522 - learning_rate: 1.0000e-04
# Epoch 141/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9375 - loss: 0.0909
# Epoch 141: val_loss improved from 0.05205 to 0.05203, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9393 - loss: 0.1327 - val_accuracy: 0.9841 - val_loss: 0.0520 - learning_rate: 1.0000e-04
# Epoch 142/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0831
# Epoch 142: val_loss did not improve from 0.05203
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9832 - loss: 0.0919 - val_accuracy: 0.9841 - val_loss: 0.0521 - learning_rate: 1.0000e-04
# Epoch 143/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0433
# Epoch 143: val_loss improved from 0.05203 to 0.05152, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9825 - loss: 0.0793 - val_accuracy: 0.9841 - val_loss: 0.0515 - learning_rate: 1.0000e-04
# Epoch 144/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9062 - loss: 0.1756
# Epoch 144: val_loss improved from 0.05152 to 0.05092, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9449 - loss: 0.1593 - val_accuracy: 0.9841 - val_loss: 0.0509 - learning_rate: 1.0000e-04
# Epoch 145/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9375 - loss: 0.1217
# Epoch 145: val_loss improved from 0.05092 to 0.05089, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9692 - loss: 0.1040 - val_accuracy: 0.9841 - val_loss: 0.0509 - learning_rate: 1.0000e-04
# Epoch 146/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.0774
# Epoch 146: val_loss improved from 0.05089 to 0.05063, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9801 - loss: 0.0740 - val_accuracy: 0.9841 - val_loss: 0.0506 - learning_rate: 1.0000e-04
# Epoch 147/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.0712
# Epoch 147: val_loss did not improve from 0.05063
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9854 - loss: 0.0676 - val_accuracy: 0.9841 - val_loss: 0.0507 - learning_rate: 1.0000e-04
# Epoch 148/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9375 - loss: 0.1765
# Epoch 148: val_loss improved from 0.05063 to 0.05040, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9635 - loss: 0.1491 - val_accuracy: 0.9841 - val_loss: 0.0504 - learning_rate: 1.0000e-04
# Epoch 149/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0585
# Epoch 149: val_loss improved from 0.05040 to 0.05029, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9807 - loss: 0.0762 - val_accuracy: 0.9841 - val_loss: 0.0503 - learning_rate: 1.0000e-04
# Epoch 150/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0798
# Epoch 150: val_loss improved from 0.05029 to 0.04992, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9710 - loss: 0.1013 - val_accuracy: 0.9841 - val_loss: 0.0499 - learning_rate: 1.0000e-04
# Epoch 151/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9375 - loss: 0.2280
# Epoch 151: val_loss improved from 0.04992 to 0.04947, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9585 - loss: 0.1500 - val_accuracy: 0.9841 - val_loss: 0.0495 - learning_rate: 1.0000e-04
# Epoch 152/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9375 - loss: 0.0896
# Epoch 152: val_loss improved from 0.04947 to 0.04928, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9695 - loss: 0.0706 - val_accuracy: 0.9841 - val_loss: 0.0493 - learning_rate: 1.0000e-04
# Epoch 153/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9375 - loss: 0.1107
# Epoch 153: val_loss did not improve from 0.04928
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9776 - loss: 0.0804 - val_accuracy: 0.9841 - val_loss: 0.0493 - learning_rate: 1.0000e-04
# Epoch 154/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0427
# Epoch 154: val_loss did not improve from 0.04928
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9773 - loss: 0.0958 - val_accuracy: 0.9841 - val_loss: 0.0494 - learning_rate: 1.0000e-04
# Epoch 155/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0525
# Epoch 155: val_loss did not improve from 0.04928
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9829 - loss: 0.0843 - val_accuracy: 0.9841 - val_loss: 0.0496 - learning_rate: 1.0000e-04
# Epoch 156/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9375 - loss: 0.2025
# Epoch 156: val_loss did not improve from 0.04928
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9410 - loss: 0.1376 - val_accuracy: 0.9841 - val_loss: 0.0497 - learning_rate: 1.0000e-04
# Epoch 157/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.1197
# Epoch 157: val_loss did not improve from 0.04928
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9577 - loss: 0.1449 - val_accuracy: 0.9841 - val_loss: 0.0498 - learning_rate: 1.0000e-04
# Epoch 158/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0322
# Epoch 158: val_loss did not improve from 0.04928
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9666 - loss: 0.0845 - val_accuracy: 0.9841 - val_loss: 0.0499 - learning_rate: 1.0000e-04
# Epoch 159/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0334
# Epoch 159: val_loss did not improve from 0.04928
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9769 - loss: 0.0731 - val_accuracy: 0.9841 - val_loss: 0.0501 - learning_rate: 1.0000e-04
# Epoch 160/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.1661
# Epoch 160: val_loss did not improve from 0.04928
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9734 - loss: 0.1035 - val_accuracy: 0.9841 - val_loss: 0.0498 - learning_rate: 1.0000e-04
# Epoch 161/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9688 - loss: 0.0919
# Epoch 161: val_loss did not improve from 0.04928
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9685 - loss: 0.0845 - val_accuracy: 0.9841 - val_loss: 0.0500 - learning_rate: 1.0000e-04
# Epoch 162/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0627
# Epoch 162: val_loss did not improve from 0.04928
#
# Epoch 162: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9893 - loss: 0.0779 - val_accuracy: 0.9841 - val_loss: 0.0499 - learning_rate: 1.0000e-04
# Epoch 163/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0280
# Epoch 163: val_loss did not improve from 0.04928
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9657 - loss: 0.1184 - val_accuracy: 0.9841 - val_loss: 0.0498 - learning_rate: 1.0000e-05
# Epoch 164/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9375 - loss: 0.1253
# Epoch 164: val_loss did not improve from 0.04928
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9631 - loss: 0.1149 - val_accuracy: 0.9841 - val_loss: 0.0497 - learning_rate: 1.0000e-05
# Epoch 165/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0671
# Epoch 165: val_loss did not improve from 0.04928
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9809 - loss: 0.0756 - val_accuracy: 0.9841 - val_loss: 0.0495 - learning_rate: 1.0000e-05
# Epoch 166/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0490
# Epoch 166: val_loss did not improve from 0.04928
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9837 - loss: 0.0727 - val_accuracy: 0.9841 - val_loss: 0.0493 - learning_rate: 1.0000e-05
# Epoch 167/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9375 - loss: 0.0929
# Epoch 167: val_loss did not improve from 0.04928
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9690 - loss: 0.0792 - val_accuracy: 0.9841 - val_loss: 0.0493 - learning_rate: 1.0000e-05
# Epoch 168/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9375 - loss: 0.1088
# Epoch 168: val_loss did not improve from 0.04928
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9679 - loss: 0.0866 - val_accuracy: 0.9841 - val_loss: 0.0493 - learning_rate: 1.0000e-05
# Epoch 169/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0433
# Epoch 169: val_loss did not improve from 0.04928
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9794 - loss: 0.0720 - val_accuracy: 0.9841 - val_loss: 0.0493 - learning_rate: 1.0000e-05
# Epoch 170/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9688 - loss: 0.0896
# Epoch 170: val_loss did not improve from 0.04928
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9780 - loss: 0.0906 - val_accuracy: 0.9841 - val_loss: 0.0493 - learning_rate: 1.0000e-05
# Epoch 171/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9688 - loss: 0.1107
# Epoch 171: val_loss improved from 0.04928 to 0.04925, saving model to ../models\fashion_MNIST\all_in.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9685 - loss: 0.0910 - val_accuracy: 0.9841 - val_loss: 0.0492 - learning_rate: 1.0000e-05
# Epoch 172/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0437
# Epoch 172: val_loss did not improve from 0.04925
#
# Epoch 172: ReduceLROnPlateau reducing learning rate to 1e-05.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9865 - loss: 0.0747 - val_accuracy: 0.9841 - val_loss: 0.0493 - learning_rate: 1.0000e-05
# Epoch 173/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9688 - loss: 0.0714
# Epoch 173: val_loss did not improve from 0.04925
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9687 - loss: 0.0904 - val_accuracy: 0.9841 - val_loss: 0.0494 - learning_rate: 1.0000e-05
# Epoch 174/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.1009
# Epoch 174: val_loss did not improve from 0.04925
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9815 - loss: 0.0784 - val_accuracy: 0.9841 - val_loss: 0.0495 - learning_rate: 1.0000e-05
# Epoch 175/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.0779
# Epoch 175: val_loss did not improve from 0.04925
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9716 - loss: 0.0850 - val_accuracy: 0.9841 - val_loss: 0.0495 - learning_rate: 1.0000e-05
# Epoch 176/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9375 - loss: 0.1176
# Epoch 176: val_loss did not improve from 0.04925
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9625 - loss: 0.0899 - val_accuracy: 0.9841 - val_loss: 0.0495 - learning_rate: 1.0000e-05
# Epoch 177/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0631
# Epoch 177: val_loss did not improve from 0.04925
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9809 - loss: 0.1010 - val_accuracy: 0.9841 - val_loss: 0.0496 - learning_rate: 1.0000e-05
# Epoch 178/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9375 - loss: 0.2439
# Epoch 178: val_loss did not improve from 0.04925
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9676 - loss: 0.1320 - val_accuracy: 0.9841 - val_loss: 0.0496 - learning_rate: 1.0000e-05
# Epoch 179/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9375 - loss: 0.2730
# Epoch 179: val_loss did not improve from 0.04925
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9654 - loss: 0.1265 - val_accuracy: 0.9841 - val_loss: 0.0495 - learning_rate: 1.0000e-05
# Epoch 180/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0983
# Epoch 180: val_loss did not improve from 0.04925
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9840 - loss: 0.0795 - val_accuracy: 0.9841 - val_loss: 0.0496 - learning_rate: 1.0000e-05
# Epoch 181/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9062 - loss: 0.1450
# Epoch 181: val_loss did not improve from 0.04925
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9588 - loss: 0.0980 - val_accuracy: 0.9841 - val_loss: 0.0498 - learning_rate: 1.0000e-05
# Epoch 182/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0377
# Epoch 182: val_loss did not improve from 0.04925
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9774 - loss: 0.1027 - val_accuracy: 0.9841 - val_loss: 0.0497 - learning_rate: 1.0000e-05
# Epoch 183/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9375 - loss: 0.1304
# Epoch 183: val_loss did not improve from 0.04925
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9775 - loss: 0.0899 - val_accuracy: 0.9841 - val_loss: 0.0497 - learning_rate: 1.0000e-05
# Epoch 184/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0317
# Epoch 184: val_loss did not improve from 0.04925
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9807 - loss: 0.0859 - val_accuracy: 0.9841 - val_loss: 0.0499 - learning_rate: 1.0000e-05
# Epoch 185/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9062 - loss: 0.2394
# Epoch 185: val_loss did not improve from 0.04925
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9621 - loss: 0.1203 - val_accuracy: 0.9841 - val_loss: 0.0499 - learning_rate: 1.0000e-05
# Epoch 186/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9375 - loss: 0.2034
# Epoch 186: val_loss did not improve from 0.04925
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9678 - loss: 0.1302 - val_accuracy: 0.9841 - val_loss: 0.0499 - learning_rate: 1.0000e-05
# Epoch 187/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0536
# Epoch 187: val_loss did not improve from 0.04925
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9798 - loss: 0.0786 - val_accuracy: 0.9841 - val_loss: 0.0498 - learning_rate: 1.0000e-05
# Epoch 188/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0544
# Epoch 188: val_loss did not improve from 0.04925
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9796 - loss: 0.0826 - val_accuracy: 0.9841 - val_loss: 0.0498 - learning_rate: 1.0000e-05
# Epoch 189/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9688 - loss: 0.1002
# Epoch 189: val_loss did not improve from 0.04925
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9670 - loss: 0.1279 - val_accuracy: 0.9841 - val_loss: 0.0498 - learning_rate: 1.0000e-05
# Epoch 190/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8750 - loss: 0.3020
# Epoch 190: val_loss did not improve from 0.04925
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9411 - loss: 0.1626 - val_accuracy: 0.9841 - val_loss: 0.0496 - learning_rate: 1.0000e-05
# Epoch 191/500
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0348
# Epoch 191: val_loss did not improve from 0.04925
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9676 - loss: 0.1044 - val_accuracy: 0.9841 - val_loss: 0.0493 - learning_rate: 1.0000e-05
# Epoch 191: early stopping
# Restoring model weights from the end of the best epoch: 171.

# %%
loss_df = pd.DataFrame(history.history)
loss_df.head()
# Out:
#    accuracy      loss  val_accuracy  val_loss  learning_rate
# 0  0.482639  0.944989      0.365079  0.782193          0.001
# 1  0.506944  0.813922      0.365079  0.723789          0.001
# 2  0.576389  0.721929      0.412698  0.668594          0.001
# 3  0.645833  0.646103      0.476190  0.614482          0.001
# 4  0.718750  0.615478      0.571429  0.567753          0.001

# %%
fn_plot_tf_hist(loss_df)
